# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("ds_salaries.csv")
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
t = data.query('employee_residence in ("AR", "US")')
t.sort_values("salary_in_usd", ascending=False)
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
# 97           97       2021               MI              FT
# 33           33       2020               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
# ..          ...        ...              ...             ...
# 565         565       2022               SE              FT
# 471         471       2022               MI              FT
# 122         122       2021               EN              FT
# 455         455       2022               MI              FT
# 579         579       2022               SE              FT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 97               Financial Data Analyst  450000             USD
# ...

# %%
data.groupby(['employee_residence']).groups



country = data['employee_residence'].unique().tolist()
countryID = list(range(1, len(li) + 1))
matr = np.column_stack((country, countryID))


df = pd.DataFrame(data = list(matr),  columns = ['country', 'country_id'])

data_merged = pd.merge(data, df, left_on='employee_residence', right_on='country')

# %%
data_merged.plot(kind="scatter", y="salary_in_usd", x="country", figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='country', ylabel='salary_in_usd'>

# %%
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []
