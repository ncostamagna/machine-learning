# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
d = {'id': [1, 2, 3], 'name': ["Nahuel", "Ulises", "Celeste"]}
user = pd.DataFrame(data=d)

# %%
user
# Out:
#    id     name
# 0   1   Nahuel
# 1   2   Ulises
# 2   3  Celeste

# %%
d = {'id': [1, 2, 5], 'name': ["nlcostamagna@gmail.com", "uconstamagna@gmai.com", "acostamagna@gmail.com"]}
address = pd.DataFrame(data=d)

# %%
address
# Out:
#    id                    name
# 0   1  nlcostamagna@gmail.com
# 1   2   uconstamagna@gmai.com
# 2   5   acostamagna@gmail.com

# %%
pd.merge(user, address, on=["id", "id"])
# Out:
#    id  name_x                  name_y
# 0   1  Nahuel  nlcostamagna@gmail.com
# 1   2  Ulises   uconstamagna@gmai.com

# %%
pd.merge(user, address, how="left", on=["id", "id"])
# Out:
#    id   name_x                  name_y
# 0   1   Nahuel  nlcostamagna@gmail.com
# 1   2   Ulises   uconstamagna@gmai.com
# 2   3  Celeste                     NaN

# %%
pd.merge(user, address, how="right", on=["id", "id"])
# Out:
#    id  name_x                  name_y
# 0   1  Nahuel  nlcostamagna@gmail.com
# 1   2  Ulises   uconstamagna@gmai.com
# 2   5     NaN   acostamagna@gmail.com

# %%
pd.merge(user, address, how="outer", on=["id", "id"])
# Out:
#    id   name_x                  name_y
# 0   1   Nahuel  nlcostamagna@gmail.com
# 1   2   Ulises   uconstamagna@gmai.com
# 2   3  Celeste                     NaN
# 3   5      NaN   acostamagna@gmail.com

# %% [markdown]
# # Dolar Analitic

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 5.5 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.30.0-py3-none-any.whl (898 kB)
#      |████████████████████████████████| 898 kB 64.7 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/nahuel/anaconda3/lib/python3.9/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: numpy>=1.17 in /home/nahuel/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.22.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/nahuel/anaconda3/lib/python3.9/site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/nahuel/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/nahuel/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 55.2 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /home/nahuel/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.30.0 kiwisolver-1.3.2 matplotlib-3.5.1

# %%
dolar = pd.read_csv("datasets/USD-ARG 08-2011_08-2021.csv")

# %%
dolar['Fecha'] =  pd.to_datetime(dolar['Fecha'], format='%d.%m.%Y')

dolar['day'] = (dolar['Fecha'] - dolar['Fecha'][len(dolar) -1]).dt.days
dolar['moneda'] = dolar['Último'].str.replace(',','.').astype(float)

# dolar['Fecha'] = [int(x.split('.')[2]) + int(x.split('.')[1]) +
 #                   int(x.split('.')[0]) for x in dolar['Fecha']]
dolar["president"] = ""

# %%
# dolar.loc[(dolar.day < 2) | (dolar.day > 2000), "president"] = "lala"

dolar.loc[(dolar.Fecha <= '2015-12-09'), "president"] = "Cristina"
dolar.loc[(dolar.Fecha > '2015-12-09') & (dolar.Fecha <= '2019-12-10'), "president"] = "Macri"
dolar.loc[(dolar.Fecha > '2019-12-10'), "president"] = "Alberto"

# %%
dolar
# Out:
#           Fecha   Último Apertura   Máximo   Mínimo  % var.   day   moneda  \
# 0    2021-09-08  98,0150  97,9080  98,0400  97,9080   0,24%  3691  98.0150
# 1    2021-09-07  97,7850  97,8625  98,0250  97,8625  -0,16%  3690  97.7850
# 2    2021-09-06  97,9400  97,9400  97,9850  97,9100   0,07%  3689  97.9400
# 3    2021-09-03  97,8700  97,8800  97,8850  97,8550   0,04%  3686  97.8700
# 4    2021-09-02  97,8300  97,7230  97,8550  97,7130   0,24%  3685  97.8300
# ...         ...      ...      ...      ...      ...     ...   ...      ...
# 2630 2011-08-05   4,1555   4,1470   4,1585   4,1430   0,18%     4   4.1555
# 2631 2011-08-04   4,1480   4,1470   4,1550   4,1470   0,00%     3   4.1480
# 2632 2011-08-03   4,1480   4,1470   4,1550   4,1420   0,04%     2   4.1480
# 2633 2011-08-02   4,1465   4,1310   4,1515   4,1310   0,35%     1   4.1465
# 2634 2011-08-01   4,1320   4,1370   4,1400   4,1290  -0,14%     0   4.1320
#
#      president
# 0      Alberto
# 1      Alberto
# 2      Alberto
# 3      Alberto
# 4      Alberto
# ...        ...
# 2630  Cristina
# 2631  Cristina
# 2632  Cristina
# 2633  Cristina
# 2634  Cristina
#
# [2635 rows x 9 columns]

# %%
#dolar.plot.line(x='day', y='moneda').line(1,1)
p1 = dolar.loc[dolar.president == "Cristina"]
p2 = dolar.loc[dolar.president == "Macri"]
p3 = dolar.loc[dolar.president == "Alberto"]
plt.plot(p1['day'], p1['moneda'])
plt.plot(p2['day'], p2['moneda'])
plt.plot(p3['day'], p3['moneda'])
plt.legend({'Cristina','Macri', 'Alberto'},loc='upper left')
plt.show()

# %%
p3['day'] = p3['day'] - p2['day'].max()
p2['day'] = p2['day'] - p1['day'].max()

p3['moneda'] = p3['moneda'] - p2['moneda'].max()
p2['moneda'] = p2['moneda'] - p1['moneda'].max()

plt.plot(p1['day'], p1['moneda'])
plt.plot(p2['day'], p2['moneda'])
plt.plot(p3['day'], p3['moneda'])
plt.legend({'Cristina','Macri', 'Alberto'},loc='upper left')
plt.show()
# Out:
# /tmp/ipykernel_259761/1430956041.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p3['day'] = p3['day'] - p2['day'].max()
# /tmp/ipykernel_259761/1430956041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2['day'] = p2['day'] - p1['day'].max()
# /tmp/ipykernel_259761/1430956041.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p3['moneda'] = p3['moneda'] - p2['moneda'].max()
# /tmp/ipykernel_259761/1430956041.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p2['moneda'] = p2['moneda'] - p1['moneda'].max()

# %%
dolar
# Out:
#           Fecha   Último Apertura   Máximo   Mínimo  % var.   day   moneda  \
# 0    2021-09-08  98,0150  97,9080  98,0400  97,9080   0,24%  3691  98.0150
# 1    2021-09-07  97,7850  97,8625  98,0250  97,8625  -0,16%  3690  97.7850
# 2    2021-09-06  97,9400  97,9400  97,9850  97,9100   0,07%  3689  97.9400
# 3    2021-09-03  97,8700  97,8800  97,8850  97,8550   0,04%  3686  97.8700
# 4    2021-09-02  97,8300  97,7230  97,8550  97,7130   0,24%  3685  97.8300
# ...         ...      ...      ...      ...      ...     ...   ...      ...
# 2630 2011-08-05   4,1555   4,1470   4,1585   4,1430   0,18%     4   4.1555
# 2631 2011-08-04   4,1480   4,1470   4,1550   4,1470   0,00%     3   4.1480
# 2632 2011-08-03   4,1480   4,1470   4,1550   4,1420   0,04%     2   4.1480
# 2633 2011-08-02   4,1465   4,1310   4,1515   4,1310   0,35%     1   4.1465
# 2634 2011-08-01   4,1320   4,1370   4,1400   4,1290  -0,14%     0   4.1320
#
#      president
# 0      Alberto
# 1      Alberto
# 2      Alberto
# 3      Alberto
# 4      Alberto
# ...        ...
# 2630  Cristina
# 2631  Cristina
# 2632  Cristina
# 2633  Cristina
# 2634  Cristina
#
# [2635 rows x 9 columns]
